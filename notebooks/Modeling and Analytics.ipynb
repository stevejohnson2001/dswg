# %% [markdown]
# ## 2.0 Models
#
# Create a number of models to predict opioid death

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import plotly.plotly as py
import plotly.figure_factory as ff
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
from plotly.graph_objs import Scatter, Figure, Layout
from IPython.display import display, HTML
init_notebook_mode(connected=True)
from os import listdir
datadir = '/home/jovyan/work/dswg/data'
print(listdir(datadir))
obs = pd.read_pickle(datadir+'/temp/obs.tmp')
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# ['medications.csv', 'temp', 'allergies.csv', 'procedures.csv', 'conditions.csv', 'careplans.csv', 'encounters.csv', 'immunizations.csv', 'patients.csv', 'observations.csv']

# %%
from IPython.display import display, HTML
display(obs.head(5))
# Out:
#                                            DATE  \
# ENCOUNTER
# 87216f21-b849-490a-a025-e2df2f042709 2009-01-28
# 87216f21-b849-490a-a025-e2df2f042709 2009-01-28
# 87216f21-b849-490a-a025-e2df2f042709 2009-01-28
# dc9874cc-7b49-4a48-8878-4be32b0b372a 2014-11-07
# 87216f21-b849-490a-a025-e2df2f042709 2009-01-28
#
#                                                                    PATIENT  \
# ENCOUNTER
# 87216f21-b849-490a-a025-e2df2f042709  545be6f8-8796-496a-ac87-9919542f724e
# 87216f21-b849-490a-a025-e2df2f042709  545be6f8-8796-496a-ac87-9919542f724e
# 87216f21-b849-490a-a025-e2df2f042709  545be6f8-8796-496a-ac87-9919542f724e
# dc9874cc-7b49-4a48-8878-4be32b0b372a  f86ec82d-004a-46df-8cdb-4226abd6886d
# 87216f21-b849-490a-a025-e2df2f042709  545be6f8-8796-496a-ac87-9919542f724e
#
#                                          CODE               DESCRIPTION  \
# ENCOUNTER
# 87216f21-b849-490a-a025-e2df2f042709   8302-2               Body Height
# 87216f21-b849-490a-a025-e2df2f042709  29463-7               Body Weight
# 87216f21-b849-490a-a025-e2df2f042709  39156-5           Body Mass Index
# dc9874cc-7b49-4a48-8878-4be32b0b372a   8302-2               Body Height
# 87216f21-b849-490a-a025-e2df2f042709   8462-4  Diastolic Blood Pressure
#
#                                       VALUE  UNITS  BIRTHDATE DEATHDATE  \
# ENCOUNTER
# 87216f21-b849-490a-a025-e2df2f042709  105.9     cm 2004-02-18       NaT
# 87216f21-b849-490a-a025-e2df2f042709   22.1     kg 2004-02-18       NaT
# 87216f21-b849-490a-a025-e2df2f042709   19.7  kg/m2 2004-02-18       NaT
# dc9874cc-7b49-4a48-8878-4be32b0b372a   48.9     cm 2014-11-07       NaT
# 87216f21-b849-490a-a025-e2df2f042709   81.5   mmHg 2004-02-18       NaT
#
#                                               SSN DRIVERS  ...   MAIDEN  \
# ENCOUNTER                                                  ...
# 87216f21-b849-490a-a025-e2df2f042709  999-22-9579     NaN  ...      NaN
# 87216f21-b849-490a-a025-e2df2f042709  999-22-9579     NaN  ...      NaN
# 87216f21-b849-490a-a025-e2df2f042709  999-22-9579     NaN  ...      NaN
# dc9874cc-7b49-4a48-8878-4be32b0b372a  999-84-5231     NaN  ...      NaN
# 87216f21-b849-490a-a025-e2df2f042709  999-22-9579     NaN  ...      NaN
#
#                                      MARITAL   RACE ETHNICITY GENDER  \
# ENCOUNTER
# 87216f21-b849-490a-a025-e2df2f042709     NaN  white    french      M
# 87216f21-b849-490a-a025-e2df2f042709     NaN  white    french      M
# 87216f21-b849-490a-a025-e2df2f042709     NaN  white    french      M
# dc9874cc-7b49-4a48-8878-4be32b0b372a     NaN  white    german      F
# 87216f21-b849-490a-a025-e2df2f042709     NaN  white    french      M
#
#                                           BIRTHPLACE  \
# ENCOUNTER
# 87216f21-b849-490a-a025-e2df2f042709  Dell Groveship
# 87216f21-b849-490a-a025-e2df2f042709  Dell Groveship
# 87216f21-b849-490a-a025-e2df2f042709  Dell Groveship
# dc9874cc-7b49-4a48-8878-4be32b0b372a      Huntership
# 87216f21-b849-490a-a025-e2df2f042709  Dell Groveship
#
#                                                                                 ADDRESS  \
# ENCOUNTER
# 87216f21-b849-490a-a025-e2df2f042709  740 Schmidt Heights Apt 24 Apple Valley Minnes...
# 87216f21-b849-490a-a025-e2df2f042709  740 Schmidt Heights Apt 24 Apple Valley Minnes...
# 87216f21-b849-490a-a025-e2df2f042709  740 Schmidt Heights Apt 24 Apple Valley Minnes...
# dc9874cc-7b49-4a48-8878-4be32b0b372a  775 Prosacco Ville Minneapolis Minnesota 55401 US
# 87216f21-b849-490a-a025-e2df2f042709  740 Schmidt Heights Apt 24 Apple Valley Minnes...
#
#                                      _merge age_at_visit  adult
# ENCOUNTER
# 87216f21-b849-490a-a025-e2df2f042709   both          5.0  False
# 87216f21-b849-490a-a025-e2df2f042709   both          5.0  False
# 87216f21-b849-490a-a025-e2df2f042709   both          5.0  False
# dc9874cc-7b49-4a48-8878-4be32b0b372a   both          0.0  False
# 87216f21-b849-490a-a025-e2df2f042709   both          5.0  False
#
# [5 rows x 25 columns]

# %%
obs[obs['CODE']=='55680006'].head(5)
# Out:
# Empty DataFrame
# Columns: [DATE, PATIENT, CODE, DESCRIPTION, VALUE, UNITS, BIRTHDATE, DEATHDATE, SSN, DRIVERS, PASSPORT, PREFIX, FIRST, LAST, SUFFIX, MAIDEN, MARITAL, RACE, ETHNICITY, GENDER, BIRTHPLACE, ADDRESS, _merge, age_at_visit, adult]
# Index: []
#
# [0 rows x 25 columns]
