# %% [markdown]
# ## 1.0 Load libraries and modules
# Make sure the Python environment is properly setup and that all of the required modules load correctly.

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import plotly.plotly as py
import plotly.figure_factory as ff
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
from plotly.graph_objs import Scatter, Figure, Layout

init_notebook_mode(connected=True)
from os import listdir
datadir = '/home/jovyan/work/dswg/data'
print(listdir(datadir))
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# ['medications.csv', 'temp', 'allergies.csv', 'procedures.csv', 'conditions.csv', 'careplans.csv', 'encounters.csv', 'immunizations.csv', 'patients.csv', 'observations.csv']

# %%
obs = pd.read_pickle(datadir+'/temp/obs.tmp')

# %% [markdown]
# ## 2.0 Find Missing Data
#
# Load the dataframe and use the Domain model to find all of the missing data

# %%
missing_data = obs[obs.isnull().any(axis=1)]
print("Shape = ",missing_data.shape)
missing_data.head(10)
# Out:
# Shape =  (112205, 25)
#                                            DATE  \
# ENCOUNTER
# 87216f21-b849-490a-a025-e2df2f042709 2009-01-28
# 87216f21-b849-490a-a025-e2df2f042709 2009-01-28
# 87216f21-b849-490a-a025-e2df2f042709 2009-01-28
# dc9874cc-7b49-4a48-8878-4be32b0b372a 2014-11-07
# 87216f21-b849-490a-a025-e2df2f042709 2009-01-28
# 87216f21-b849-490a-a025-e2df2f042709 2009-01-28
# 10b30d46-89f2-4029-98af-e11cc3cae62d 2008-06-17
# 10b30d46-89f2-4029-98af-e11cc3cae62d 2008-06-17
# 10b30d46-89f2-4029-98af-e11cc3cae62d 2008-06-17
# 10b30d46-89f2-4029-98af-e11cc3cae62d 2008-06-17
#
#                                                                    PATIENT  \
# ENCOUNTER
# 87216f21-b849-490a-a025-e2df2f042709  545be6f8-8796-496a-ac87-9919542f724e
# 87216f21-b849-490a-a025-e2df2f042709  545be6f8-8796-496a-ac87-9919542f724e
# 87216f21-b849-490a-a025-e2df2f042709  545be6f8-8796-496a-ac87-9919542f724e
# dc9874cc-7b49-4a48-8878-4be32b0b372a  f86ec82d-004a-46df-8cdb-4226abd6886d
# ...

# %% [markdown]
# ### 3.1 Find Inconsistent Data

# %% [markdown]
# ### 3.2 Impute Missing Data

# %% [markdown]
# ## 4.0 Visualize Data Quality Issues
