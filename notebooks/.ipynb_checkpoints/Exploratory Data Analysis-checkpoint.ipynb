# %% [markdown]
# # 1.0 Load libraries and modules
# Make sure the Python environment is properly setup and that all of the required modules load correctly.

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import plotly.plotly as py
import plotly.figure_factory as ff
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
from plotly.graph_objs import Scatter, Figure, Layout
from IPython.display import display, HTML
init_notebook_mode(connected=True)
from os import listdir
datadir = '/home/jovyan/work/dswg/data'
print(listdir(datadir))
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# ['medications.csv', 'temp', 'allergies.csv', 'procedures.csv', 'conditions.csv', 'careplans.csv', 'encounters.csv', 'immunizations.csv', 'patients.csv', 'observations.csv']

# %%
#Load the data
fips = [27000+i for i in range(1,174,2)]
#print(fips)
pop = [np.random.randint(1,100) for i in range(0,len(fips))]
#print(pop)
prevalance = np.random.normal(size=100)

# %% [markdown]
# # 2.0 Load Data
# Load the patient and observations (labs) data from the .csv file that we received from the extract.  Convert dates and other fields to the proper format when reading the file.
#
# Displaying the first 5 rows of the data is a good way to look for obvious issues before working with the data in more detail.

# %%
patients = pd.read_csv(datadir + '/patients.csv', index_col=0, header=0, parse_dates=[1,2])
observations = pd.read_csv(datadir + '/observations.csv', header=0, parse_dates=[0])
encounters = pd.read_csv(datadir + '/encounters.csv', index_col=0, header=0, parse_dates=[2])
medications = pd.read_csv(datadir + '/medications.csv', index_col=0, header=0, parse_dates=[2])
display(patients.head(5))
display(encounters.head(5))
display(observations.head(5))
# Out:
#                                       BIRTHDATE  DEATHDATE          SSN  \
# ID
# 545be6f8-8796-496a-ac87-9919542f724e 2004-02-18        NaT  999-22-9579
# 7e354bf5-99c6-413d-b37c-b779dd103583 1996-05-28        NaT  999-93-9114
# f86ec82d-004a-46df-8cdb-4226abd6886d 2014-11-07        NaT  999-84-5231
# 556e6a09-12c0-40fc-8f68-9989df047485 1959-10-29 2004-10-21  999-79-5940
# 58ec9442-891c-4855-9008-3e8d700eb5b8 2004-06-03        NaT  999-48-8276
#
#                                         DRIVERS    PASSPORT PREFIX  \
# ID
# 545be6f8-8796-496a-ac87-9919542f724e        NaN         NaN    NaN
# 7e354bf5-99c6-413d-b37c-b779dd103583  S99976555  X29508953X    Mr.
# f86ec82d-004a-46df-8cdb-4226abd6886d        NaN         NaN    NaN
# 556e6a09-12c0-40fc-8f68-9989df047485  S99947417  X40810024X    Mr.
# 58ec9442-891c-4855-9008-3e8d700eb5b8        NaN         NaN    NaN
#
#                                             FIRST           LAST SUFFIX  \
# ID
# 545be6f8-8796-496a-ac87-9919542f724e      Noble66       Hintz995    NaN
# 7e354bf5-99c6-413d-b37c-b779dd103583     Colin861     Barrows492    NaN
# f86ec82d-004a-46df-8cdb-4226abd6886d     Ashley34      Becker968    NaN
# 556e6a09-12c0-40fc-8f68-9989df047485  Randolph418  Runolfsson901    NaN
# 58ec9442-891c-4855-9008-3e8d700eb5b8      Lili474       Johns824    NaN
#
#                                      MAIDEN MARITAL   RACE ETHNICITY GENDER  \
# ID
# 545be6f8-8796-496a-ac87-9919542f724e    NaN     NaN  white    french      M
# 7e354bf5-99c6-413d-b37c-b779dd103583    NaN     NaN  white    polish      M
# f86ec82d-004a-46df-8cdb-4226abd6886d    NaN     NaN  white    german      F
2009-01-28  545be6f8-8796-496a-ac87-9919542f724e
# 1 2009-01-28  545be6f8-8796-496a-ac87-9919542f724e
# 2 2009-01-28  545be6f8-8796-496a-ac87-9919542f724e
# 3 2014-11-07  f86ec82d-004a-46df-8cdb-4226abd6886d
# 4 2009-01-28  545be6f8-8796-496a-ac87-9919542f724e
#
#                               ENCOUNTER     CODE               DESCRIPTION  \
# 0  87216f21-b849-490a-a025-e2df2f042709   8302-2               Body Height
# 1  87216f21-b849-490a-a025-e2df2f042709  29463-7               Body Weight
# 2  87216f21-b849-490a-a025-e2df2f042709  39156-5           Body Mass Index
# 3  dc9874cc-7b49-4a48-8878-4be32b0b372a   8302-2               Body Height
# 4  87216f21-b849-490a-a025-e2df2f042709   8462-4  Diastolic Blood Pressure
#
#    VALUE  UNITS
# 0  105.9     cm
# 1   22.1     kg
# 2   19.7  kg/m2
# 3   48.9     cm
# 4   81.5   mmHg

# %%
overdose_encounters = encounters[encounters['REASONCODE']==55680006]
print(len(overdose_encounters))
overdose_encounters.head(5)
# Out:
# 41
#                                             DATE  \
# ID
# 85134770-5582-49e5-983f-90b031b220f7  2008-03-27
# b77882d4-e308-440a-91ec-0e6174ccc475  2010-10-12
# 2371e545-043c-42d3-84d1-be49df1801c8  1990-11-07
# ea4a54ff-3939-4d7d-b692-afd44ea5bec7  1994-03-13
# 98f5e304-00ad-4ce4-8c51-d329e959c66a  1995-10-10
#
#                                                                    PATIENT  \
# ID
# 85134770-5582-49e5-983f-90b031b220f7  3ff78458-b80e-4c45-9c6f-9417e8f103d6
# b77882d4-e308-440a-91ec-0e6174ccc475  3ff78458-b80e-4c45-9c6f-9417e8f103d6
# 2371e545-043c-42d3-84d1-be49df1801c8  11889e1f-99ec-4b37-96b5-6679a8f885c3
# ea4a54ff-3939-4d7d-b692-afd44ea5bec7  11889e1f-99ec-4b37-96b5-6679a8f885c3
# 98f5e304-00ad-4ce4-8c51-d329e959c66a  11889e1f-99ec-4b37-96b5-6679a8f885c3
#
#                                           CODE               DESCRIPTION  \
# ID
# 85134770-5582-49e5-983f-90b031b220f7  50849002  Emergency Room Admission
# b77882d4-e308-440a-91ec-0e6174ccc475  50849002  Emergency Room Admission
# 2371e545-043c-42d3-84d1-be49df1801c8  50849002  Emergency Room Admission
# ea4a54ff-3939-4d7d-b692-afd44ea5bec7  50849002  Emergency Room Admission
# 98f5e304-00ad-4ce4-8c51-d329e959c66a  50849002  Emergency Room Admission
#
#                                       REASONCODE REASONDESCRIPTION
# ID
# 85134770-5582-49e5-983f-90b031b220f7  55680006.0     Drug overdose
# b77882d4-e308-440a-91ec-0e6174ccc475  55680006.0     Drug overdose
# 2371e545-043c-42d3-84d1-be49df1801c8  55680006.0     Drug overdose
# ea4a54ff-3939-4d7d-b692-afd44ea5bec7  55680006.0     Drug overdose
# 98f5e304-00ad-4ce4-8c51-d329e959c66a  55680006.0     Drug overdose

# %%
encounters[encounters['PATIENT']=='3ff78458-b80e-4c45-9c6f-9417e8f103d6']
# Out:
#                                             DATE  \
# ID
# 85134770-5582-49e5-983f-90b031b220f7  2008-03-27
# 0dde55cc-668b-4f10-8962-93a26afc845b  2008-05-22
# 7b011d3d-75e1-4f38-a576-713a59b2a3fd                                       NaN
# d4c709a4-9057-4dff-887c-3773e49aee8c                                       NaN
# b56212e5-7115-4abb-9f50-05aaac57a090                                       NaN
# 3a2f5341-c564-4b5c-a642-a6b77fc93933                                       NaN
# 5b47210d-edb9-4d4a-9a63-9b6d1291723c                                       NaN
#
# [129 rows x 6 columns]

# %% [markdown]
# # 3.0 Exploratory Data Analysis
#
# Use the power of Matplotlib, Seaborn and Plotly to easily explore the data through rich visualizations including graphs, distributions and maps of the data.
#
# The graphs are interactive through hovering and selecting of elements.  The graphic can be exported to be included in other documents.

# %%
values = pop
endpts = list(np.mgrid[min(values):max(values):4j])

colorscale = ["#030512","#1d1d3b","#323268","#3d4b94","#3e6ab0",
              "#4989bc","#60a7c7","#85c5d3","#b7e0e4","#eafcfd"]  # Blues
colorscale = [
    'rgb(68.0, 1.0, 84.0)',
    'rgb(66.0, 64.0, 134.0)',
    'rgb(38.0, 130.0, 142.0)',
    'rgb(63.0, 188.0, 115.0)',
    'rgb(216.0, 226.0, 25.0)'
]  # Green / Yellow

fig = ff.create_choropleth(
    fips=fips, values=values, scope=['Minnesota'], show_state_data=True,
    colorscale=colorscale, 
    binning_endpoints=endpts, 
    round_legend_values=True,
    plot_bgcolor='rgb(229,229,229)',
    paper_bgcolor='rgb(229,229,229)',
    legend_title='Prevalance by County',
    county_outline={'color': 'rgb(0,0,0)', 'width': 0.5},
    state_outline={'color': 'rgb(0,0,0)', 'width': 1},
    exponent_format=True,
)

iplot(fig, filename='choropleth_MN')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-13-5fdef6739498> in <module>()
#      22     county_outline={'color': 'rgb(0,0,0)', 'width': 0.5},
#      23     state_outline={'color': 'rgb(0,0,0)', 'width': 1},
# ---> 24     exponent_format=True,
#      25 )
#      26
#
# /opt/conda/lib/python3.6/site-packages/plotly/figure_factory/_county_choropleth.py in create_choropleth(fips, values, scope, binning_endpoints, colorscale, order, simplify_county, simplify_state, asp, show_hover, show_state_data, state_outline, county_outline, centroid_marker, round_legend_values, exponent_format, legend_title, **layout_options)
#     563     if not gp or not shapefile or not shapely:
#     564         raise ImportError(
# --> 565             "geopandas, pyshp and shapely must be installed for this figure "
#     566             "factory.\n\nRun the following commands in the terminal to "
#     567             "ensure that the correct versions of the modules are installed:\n"
#
# ImportError: geopandas, pyshp and shapely must be installed for this figure factory.
#
# Run the following commands in the terminal to ensure that the correct versions of the modules are installed:
# `pip install geopandas==0.3.0`
# `pip install pyshp==1.2.10`
# `pip install shapely==1.6.3`

# %%
sns.countplot(x='RACE', data=patients)

# %%
g = sns.countplot(x='ETHNICITY', data=patients)
z = plt.xticks(rotation=-45)

# %%
sns.distplot(prevalance)

# %% [markdown]
# # 3.0 Transform the Data
#
# Use the power of Pandas Dataframes to transform the data.  Add new columns as calculations from existing columns, join the data together and get it into the format you need for analysis.

# %%
obs = pd.merge(observations, patients, left_on='PATIENT', how='left', right_index=True, indicator=True)
obs['age_at_visit'] = round((pd.to_datetime(obs['DATE']) - pd.to_datetime(obs['BIRTHDATE'])).dt.days/365)
obs['adult'] = np.where(obs['age_at_visit'] >= 18, True, False)
#obs[obs['adult']].head(5)

# %%
enc2 = encounters.reset_index()
print(enc2.columns)
enc2.columns = ['ENC_' + name for name in enc2.columns]
enc2.head(5)
# Out:
# Index(['ID', 'DATE', 'PATIENT', 'CODE', 'DESCRIPTION', 'REASONCODE',
#        'REASONDESCRIPTION'],
#       dtype='object')
#                                  ENC_ID    ENC_DATE  \
# 0  87216f21-b849-490a-a025-e2df2f042709  2009-01-28
# 1  20081f28-9818-42f9-ab2e-903287bda3f5  1994-10-27
# 2  dc9874cc-7b49-4a48-8878-4be32b0b372a  2014-11-07
# 3  10b30d46-89f2-4029-98af-e11cc3cae62d  2008-06-17
# 4  6c0896d3-2cdd-4d04-964d-0f8e6359d101  2010-02-03
#
#                             ENC_PATIENT   ENC_CODE  \
# 0  545be6f8-8796-496a-ac87-9919542f724e  185349003
# 1  556e6a09-12c0-40fc-8f68-9989df047485  185349003
# 2  f86ec82d-004a-46df-8cdb-4226abd6886d  185349003
# 3  7e354bf5-99c6-413d-b37c-b779dd103583  185349003
# 4  545be6f8-8796-496a-ac87-9919542f724e  185349003
#
#                       ENC_DESCRIPTION  ENC_REASONCODE ENC_REASONDESCRIPTION
# 0  Encounter for check up (procedure)             NaN                   NaN
# 1  Encounter for check up (procedure)             NaN                   NaN
# 2  Encounter for check up (procedure)             NaN                   NaN
# 3  Encounter for check up (procedure)             NaN                   NaN
# 4  Encounter for check up (procedure)             NaN                   NaN

# %%
obs.head(5)
# Out:
#         DATE                               PATIENT  \
# 0 2009-01-28  545be6f8-8796-496a-ac87-9919542f724e
# 1 2009-01-28  545be6f8-8796-496a-ac87-9919542f724e
# 2 2009-01-28  545be6f8-8796-496a-ac87-9919542f724e
# 3 2014-11-07  f86ec82d-004a-46df-8cdb-4226abd6886d
# 4 2009-01-28  545be6f8-8796-496a-ac87-9919542f724e
#
#                               ENCOUNTER     CODE               DESCRIPTION  \
# 0  87216f21-b849-490a-a025-e2df2f042709   8302-2               Body Height
# 1  87216f21-b849-490a-a025-e2df2f042709  29463-7               Body Weight
# 2  87216f21-b849-490a-a025-e2df2f042709  39156-5           Body Mass Index
# 3  dc9874cc-7b49-4a48-8878-4be32b0b372a   8302-2               Body Height
# 4  87216f21-b849-490a-a025-e2df2f042709   8462-4  Diastolic Blood Pressure
#
#    VALUE  UNITS  BIRTHDATE DEATHDATE          SSN  ...   MAIDEN MARITAL  \
# 0  105.9     cm 2004-02-18       NaT  999-22-9579  ...      NaN     NaN
# 1   22.1     kg 2004-02-18       NaT  999-22-9579  ...      NaN     NaN
# 2   19.7  kg/m2 2004-02-18       NaT  999-22-9579  ...      NaN     NaN
# 3   48.9     cm 2014-11-07       NaT  999-84-5231  ...      NaN     NaN
# 4   81.5   mmHg 2004-02-18       NaT  999-22-9579  ...      NaN     NaN
#
#     RACE ETHNICITY GENDER      BIRTHPLACE  \
# 0  white    french      M  Dell Groveship
# 1  white    french      M  Dell Groveship
# 2  white    french      M  Dell Groveship
# 3  white    german      F      Huntership
# 4  white    french      M  Dell Groveship
#
#                                              ADDRESS _merge age_at_visit  \
# 0  740 Schmidt Heights Apt 24 Apple Valley Minnes...   both          5.0
# 1  740 Schmidt Heights Apt 24 Apple Valley Minnes...   both          5.0
# 2  740 Schmidt Heights Apt 24 Apple Valley Minnes...   both          5.0
# 3  775 Prosacco Ville Minneapolis Minnesota 55401 US   both          0.0
# 4  740 Schmidt Heights Apt 24 Apple Valley Minnes...   both          5.0
#
#    adult
# 0  False
# 1  False
# 2  False
# 3  False
# 4  False
#
# [5 rows x 26 columns]

# %%
obs2 = obs.merge(enc2, how='outer', left_on='ENCOUNTER', right_on='ENC_ID')

# %%
obs = obs2

# %%
print(obs.shape)
print(obs2.shape)
display(obs.head(5))
display(obs2.head(5))
# Out:
# (112205, 26)
# (126852, 33)
#         DATE                               PATIENT  \
# 0 2009-01-28  545be6f8-8796-496a-ac87-9919542f724e
# 1 2009-01-28  545be6f8-8796-496a-ac87-9919542f724e
# 2 2009-01-28  545be6f8-8796-496a-ac87-9919542f724e
# 3 2014-11-07  f86ec82d-004a-46df-8cdb-4226abd6886d
# 4 2009-01-28  545be6f8-8796-496a-ac87-9919542f724e
#
#                               ENCOUNTER     CODE               DESCRIPTION  \
# 0  87216f21-b849-490a-a025-e2df2f042709   8302-2               Body Height
# 1  87216f21-b849-490a-a025-e2df2f042709  29463-7               Body Weight
# 2  87216f21-b849-490a-a025-e2df2f042709  39156-5           Body Mass Index
# 3  dc9874cc-7b49-4a48-8878-4be32b0b372a   8302-2               Body Height
# 4  87216f21-b849-490a-a025-e2df2f042709   8462-4  Diastolic Blood Pressure
#
#    VALUE  UNITS  BIRTHDATE DEATHDATE          SSN  ...   MAIDEN MARITAL  \
# 0  105.9     cm 2004-02-18       NaT  999-22-9579  ...      NaN     NaN
# 1   22.1     kg 2004-02-18       NaT  999-22-9579  ...      NaN     NaN
# 2   19.7  kg/m2 2004-02-18       NaT  999-22-9579  ...      NaN     NaN
# 3   48.9     cm 2014-11-07       NaT  999-84-5231  ...      NaN     NaN
# 4   81.5   mmHg 2004-02-18       NaT  999-22-9579  ...      NaN     NaN
#
#     RACE ETHNICITY GENDER      BIRTHPLACE  \
# 0  white    french      M  Dell Groveship
# 1  white    french      M  Dell Groveship
# 2  white    french      M  Dell Groveship
# 3  white    german      F      Huntership
# 4  white    french      M  Dell Groveship
#
#                                              ADDRESS _merge age_at_visit  \
# 0  740 Schmidt Heights Apt 24 Apple Valley Minnes...   both          5.0
# 1  740 Schmidt Heights Apt 24 Apple Valley Minnes...   both          5.0
# 2  740 Schmidt Heights Apt 24 Apple Valley Minnes...   both          5.0
# 3  775 Prosacco Ville Minneapolis Minnesota 55401 US   both          0.0
# 4  740 Schmidt Heights Apt 24 Apple Valley Minnes...   both          5.0
#
#    adult
# 0  False
# 1  False
# 2  False
# 3  False
# 4  False
#
# [5 rows x 26 columns]
#         DATE                               PATIENT  \
# 0 2009-01-28  545be6f8-8796-496a-ac87-9919542f724e
# 1 2009-01-28  545be6f8-8796-496a-ac87-9919542f724e
# 2 2009-01-28  545be6f8-8796-496a-ac87-9919542f724e
# 3 2009-01-28  545be6f8-8796-496a-ac87-9919542f724e
# 4 2009-01-28  545be6f8-8796-496a-ac87-9919542f724e
#
#                               ENCOUNTER     CODE               DESCRIPTION  \
# 0  87216f21-b849-490a-a025-e2df2f042709   8302-2               Body Height
# 1  87216f21-b849-490a-a025-e2df2f042709  29463-7               Body Weight
# 2  87216f21-b849-490a-a025-e2df2f042709  39156-5           Body Mass Index
# 3  87216f21-b849-490a-a025-e2df2f042709   8462-4  Diastolic Blood Pressure
# 4  87216f21-b849-490a-a025-e2df2f042709   8480-6   Systolic Blood Pressure
#
#    VALUE  UNITS  BIRTHDATE DEATHDATE          SSN          ...           \
# 0  105.9     cm 2004-02-18       NaT  999-22-9579          ...
# 1   22.1     kg 2004-02-18       NaT  999-22-9579          ...
# 2   19.7  kg/m2 2004-02-18       NaT  999-22-9579          ...
# 3   81.5   mmHg 2004-02-18       NaT  999-22-9579          ...
# 4  137.5   mmHg 2004-02-18       NaT  999-22-9579          ...
#
#   _merge age_at_visit  adult                                ENC_ID  \
# 0   both          5.0  False  87216f21-b849-490a-a025-e2df2f042709
# 1   both          5.0  False  87216f21-b849-490a-a025-e2df2f042709
# 2   both          5.0  False  87216f21-b849-490a-a025-e2df2f042709
# 3   both          5.0  False  87216f21-b849-490a-a025-e2df2f042709
# 4   both          5.0  False  87216f21-b849-490a-a025-e2df2f042709
#
#      ENC_DATE                           ENC_PATIENT   ENC_CODE  \
# 0  2009-01-28  545be6f8-8796-496a-ac87-9919542f724e  185349003
# 1  2009-01-28  545be6f8-8796-496a-ac87-9919542f724e  185349003
# 2  2009-01-28  545be6f8-8796-496a-ac87-9919542f724e  185349003
# 3  2009-01-28  545be6f8-8796-496a-ac87-9919542f724e  185349003
# 4  2009-01-28  545be6f8-8796-496a-ac87-9919542f724e  185349003
#
#                       ENC_DESCRIPTION ENC_REASONCODE ENC_REASONDESCRIPTION
# 0  Encounter for check up (procedure)            NaN                   NaN
# 1  Encounter for check up (procedure)            NaN                   NaN
# 2  Encounter for check up (procedure)            NaN                   NaN
# 3  Encounter for check up (procedure)            NaN                   NaN
# 4  Encounter for check up (procedure)            NaN                   NaN
#
# [5 rows x 33 columns]

# %%
obs[obs['ENC_REASONCODE'].notnull()].head(5)
#obs.dtypes
# Out:
#           DATE                               PATIENT  \
# 64  2011-02-11  9e96975e-60fa-46a6-9a51-c2f771ae664e
# 126 2013-12-16  58ec9442-891c-4855-9008-3e8d700eb5b8
# 157 2012-10-30  7e354bf5-99c6-413d-b37c-b779dd103583
# 192 2014-11-26  545be6f8-8796-496a-ac87-9919542f724e
# 269 2001-11-08  556e6a09-12c0-40fc-8f68-9989df047485
#
#                                 ENCOUNTER    CODE  \
# 64   2d21a0b1-2b1e-4ae3-bebf-2ef5ed30db9b  8331-1
# 126  33091c18-7048-4714-8165-85596ac49ea7  8331-1
# 157  60abb760-efd5-4d46-adca-0434519cfbce  8331-1
# 192  263a12c6-9b64-460e-b916-0353304caf57  8331-1
# 269  0aed7c34-12a8-467c-bbd2-06db10058b32  4548-4
#
#                                   DESCRIPTION VALUE UNITS  BIRTHDATE  \
# 64                           Oral temperature  38.7   Cel 2010-12-01
# 126                          Oral temperature  37.5   Cel 2004-06-03
# 157                          Oral temperature  37.8   Cel 1996-05-28
# 192                          Oral temperature  37.9   Cel 2004-02-18
# 269  Hemoglobin A1c/Hemoglobin.total in Blood   6.3     % 1959-10-29
#
#      DEATHDATE          SSN                  ...                   _merge  \
# 64         NaT  999-45-6620                  ...                     both
# 126        NaT  999-48-8276                  ...                     both
# 157        NaT  999-93-9114                  ...                     both
# 192        NaT  999-22-9579                  ...                     both
# 269 2004-10-21  999-79-5940                  ...                     both
#
#     age_at_visit  adult                                ENC_ID    ENC_DATE  \
# 64           0.0  False  2d21a0b1-2b1e-4ae3-bebf-2ef5ed30db9b  2011-02-11
# 126         10.0  False  33091c18-7048-4714-8165-85596ac49ea7  2013-12-16
# 157         16.0  False  60abb760-efd5-4d46-adca-0434519cfbce  2012-10-30
# 192         11.0  False  263a12c6-9b64-460e-b916-0353304caf57  2014-11-26
# 269         42.0   True  0aed7c34-12a8-467c-bbd2-06db10058b32  2001-11-02
#
#                               ENC_PATIENT   ENC_CODE        ENC_DESCRIPTION  \
# 64   9e96975e-60fa-46a6-9a51-c2f771ae664e  185345009  Encounter for symptom
# 126  58ec9442-891c-4855-9008-3e8d700eb5b8  185345009  Encounter for symptom
# 157  7e354bf5-99c6-413d-b37c-b779dd103583  185345009  Encounter for symptom
# 192  545be6f8-8796-496a-ac87-9919542f724e  185345009  Encounter for symptom
# 269  556e6a09-12c0-40fc-8f68-9989df047485  185347001  Encounter for problem
#
#     ENC_REASONCODE                  ENC_REASONDESCRIPTION
# 64      43878008.0   Streptococcal sore throat (disorder)
# 126    195662009.0     Acute viral pharyngitis (disorder)
# 157    195662009.0     Acute viral pharyngitis (disorder)
# 192     43878008.0   Streptococcal sore throat (disorder)
# 269     94260004.0  Secondary malignant neoplasm of colon
#
# [5 rows x 33 columns]

# %%
# Out:
# (112205, 33)

# %%
#obs[obs['ENC_REASONCODE']==55680006.0].head(5)
#obs[obs['ENC_REASONCODE']==43878008.0].head(5)
obs2[obs2['ENC_ID']=='85134770-5582-49e5-983f-90b031b220f7'].head(5)
# Out:
#        DATE PATIENT ENCOUNTER CODE DESCRIPTION VALUE UNITS BIRTHDATE  \
# 112399  NaT     NaN       NaN  NaN         NaN   NaN   NaN       NaT
#
#        DEATHDATE  SSN          ...          _merge age_at_visit adult  \
# 112399       NaT  NaN          ...             NaN          NaN   NaN
#
#                                       ENC_ID    ENC_DATE  \
# 112399  85134770-5582-49e5-983f-90b031b220f7  2008-03-27
#
#                                  ENC_PATIENT  ENC_CODE  \
# 112399  3ff78458-b80e-4c45-9c6f-9417e8f103d6  50849002
#
#                  ENC_DESCRIPTION ENC_REASONCODE ENC_REASONDESCRIPTION
# 112399  Emergency Room Admission     55680006.0         Drug overdose
#
# [1 rows x 33 columns]

# %%
w = obs[obs['CODE']=='29463-7']
print('Number of patients: {:,}'.format(len(w)))
weights = w['VALUE'].astype(np.float)
mean = np.mean(weights)
print('Avg weight: ',mean)
sns.distplot(weights)
plt.xlabel("WEIGHT (kg)")
plt.show()
# Out:
# Number of patients: 10,506
# Avg weight:  71.1310965163

# %%
weight_obs = pd.DataFrame()
weight_obs['gender'] = obs['GENDER']
weight_obs['value'] = weights
weight_obs['adult'] = obs['adult']
sns.set(style="darkgrid")
g = sns.FacetGrid(weight_obs, row= 'adult', col='gender', margin_titles=True)
bins = np.linspace(0, 60, 13)
g.map(plt.hist, 'value', color="steelblue", lw=0, normed=True)

# %% [markdown]
# ### 3.1 Save the Dataframes
#
# Write all of the dataframes to disk for the next step

# %%
obs.to_pickle(datadir+'/temp/obs.tmp')
